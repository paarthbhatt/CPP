# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def pattern1(n):
    for i in range(n):
        for j in range(n):
            print("* ", end="")
        print()
pattern1(2)
# Out:
# * *
# * *
